# %% [markdown]
# # Cauchy Distribution

# %%
import numpy as np

import matplotlib.pyplot as plt

jtplot.style(figsize=(15, 9))

# %% [markdown]
# ## Experiments

# %%
N = 5_000 # number of experiments
k = 1_000

cauchy_mean = [np.random.standard_cauchy(k).mean() for i in range(N)]
normal_mean = [np.random.standard_normal(k).mean() for i in range(N)]

fig, ax = plt.subplots(2, figsize=(21, 15))
ax[0].bar(np.arange(N), cauchy_mean, color='g')
ax[0].set_title('Mean in Cauchy Distribution')

ax[1].bar(np.arange(N), normal_mean, color='b')
ax[1].set_title('Mean in Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Mean in Normal Distribution')
