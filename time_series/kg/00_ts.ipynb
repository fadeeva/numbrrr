# %% [markdown]
# # the Basics

# %%
import pandas as pd
import numpy as np

from random import gauss
from random import random

from pandas.plotting import autocorrelation_plot

import itertools

import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

import matplotlib.pyplot as plt
import seaborn as sns

jtplot.style(figsize=(15, 9))

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Passengers dataset

# %%
series = pd.read_csv('data/passengers.csv', parse_dates=True)
series.set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# decomposition

decomposition_additive = sm.tsa.seasonal_decompose(series['passengers'], period=12)
decomposition_multiplicative = sm.tsa.seasonal_decompose(series['passengers'], period=12, model='multiplicative') 

fig, ax = plt.subplots(4, 2, figsize=(21, 13))
decomposition_additive.observed.plot(ax=ax[0, 0])
decomposition_additive.trend.plot(ax=ax[1, 0])
decomposition_additive.seasonal.plot(ax=ax[2, 0])
decomposition_additive.resid.plot(ax=ax[3, 0])

decomposition_multiplicative.observed.plot(ax=ax[0, 1])
decomposition_multiplicative.trend.plot(ax=ax[1, 1])
decomposition_multiplicative.seasonal.plot(ax=ax[2, 1])
decomposition_multiplicative.resid.plot(ax=ax[3, 1]);

# %%
decomposition_multiplicative = sm.tsa.seasonal_decompose(series['passengers'], period=12, model='multiplicative') 
decomposition_multiplicative.plot();

# %%
decomposition_additive = sm.tsa.seasonal_decompose(series['passengers'], period=12) 
decomposition_additive.plot();

# %% [markdown]
# ### Changes in level of savings in the US

# %%
series = pd.read_csv('data/savings_change.csv', parse_dates=True)
series.set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
decomposition = sm.tsa.seasonal_decompose(series['delta_val'], period=12) 
decomposition.plot();

# %% [markdown]
# ### Annual averages of the daily sunspot areas

# %%
series = pd.read_csv('data/sunspots.csv', parse_dates=True)
series.set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
decomposition = sm.tsa.seasonal_decompose(series['avg_sunspot_area'], period=12) 
decomposition.plot();

# %%
decomposition = sm.tsa.seasonal_decompose(series['avg_sunspot_area'], period=12, model='multiplicative') 
decomposition.plot();
